# %% [markdown]
# ### Часть 1. Программирование на Python

# %% [markdown]
# [ссылка на контест](http://45.77.142.102/cgi-bin/new-client?contest_id=11)

# %% [markdown]
# ### Часть 2. Проверка статистических гипотез

# %% [markdown]
# На платформе Delivery Club рестораны с быстрой скоростью доставки (готовка блюда + доставка блюда курьером до клиента), как правило - это рестораны, которые пользуются наибольшей популярность среди пользователей и получают наивысшую оценку (5 баллов).

# %% [markdown]
# Дан датасет **quality_restaurants.csv**, который преставляет из себя выборку с характеристиками некоторых ресторанов платформы DC.
#
# *avg_cook_time* - среднее время готовки ресторана,
#
# *avg_rest_toclient_time* - среднее время доставки блюда курьером ресторана до клиента,
#
# *rating* - бальная оценка ресторана (средний пользовательский рейтинг).
#
# *restaurant_id* - идентификатор ресторана
#
# *city_id* - идентификатор города

# %% [markdown]
# ### Задание 1

# %% [markdown]
# Есть ли разница между **средним временем готовки ~доставки~ ресторанов с рейтингом 5 звезд, 4 звезды, меньше 4 звезд.** При оценке использовать непараметрический критерий.

# %%
# место для решения

# %% [markdown]
# ### Задание 2

# %% [markdown]
# Для **города 1 ~23~** рассчитать силу взаимосвязи между среднем временем готовки ресторана и среднем временем доставки. Позволяют ли полученные данные говорить о существовании связи?

# %%
# место для решения

# %% [markdown]
# ### Часть 3. SQL

# %% [markdown]
# Дана таблица **ORDERS** со следующими столбцами: `id` (идентификатор заказа), `city_id` (идентификатор города), `user_id` (идентификатор клиента).
# Также дана таблица **CITIES**, поля - `id` (идентификатор города), `city_name` (название города).
#
# Задача: написать SQL-запрос, отвечающий на следующий вопрос: сколько уникальных клиентов выполнили заказ в городах на букву П.

# %% [markdown]
# ```sql
# SELECT COUNT(*) FROM (SELECT user_id FROM (SELECT * FROM ORDERS WHERE city_id IN (SELECT id FROM CITIES WHERE LEFT(city_name,1)="П")) tbl0 GROUP BY user_id) tbl1
# -- ниже два других варианта
# ```

# %% [markdown]
# Дана таблица **CLIENTS** со следующими столбцами: `id` (идентификатор клиента), `point` (местоположение клиента).
# Также дана таблица **RESTAURANTS**, поля - `id` (идентификатор ресторана), `point` (местоположение ресторана).
#
# Задача: написать SQL-запрос, отвечающий на следующий вопрос: какое среднее расстояние между каждым клиентом и каждым рестораном.
#
# _Примечание_: функция для вычисления расстояни между 2 местоположениями - `st_distance(point1, point2)`.

# %% [markdown]
# Дана таблица **COURIERS** со следующими столбцами: `id` (идентификатор курьера), `city_id` (идентификатор города).
# Также дана таблица **ORDERS**, поля - `id` (идентификатор заказа), `date` (дата заказа) и `courier_id` (идентификатор курьера, который отвозил заказ).
#
# Задача: написать SQL-запрос, отвечающий на следующий вопрос: сколько заказов было в каждом из городов 11 октября 2019 года, интересуют только города с суммарным количеством заказов больше 10000.
#
# _Примечание_: в таблице **COURIERS** каждый курьер уникален, также стоит учесть, что каждый день могут работать разные курьеры.
